# %%
# Import dependencies
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import scanpy as sc
import scanpy.external as sce
import seaborn as sns
import anndata
import matplotlib.pyplot as plt
import yaml
import scvi
import ray
import hyperopt
from ray import tune
from scvi import autotune

# Print date and time:
import datetime
e = datetime.datetime.now()
print ("Current date and time = %s" % e)

# Set other settings
sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
# Out:
# /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
#   self.seed = seed
# /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
#   self.dl_pin_memory_gpu_training = (
# /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# Current date and time = 2024-09-04 11:24:27.016520
# -----
# anndata     0.9.1
# scanpy      1.9.3
# -----
# PIL                         9.4.0
# absl                        NA
# aiohttp                     3.9.5
# aiosignal                   1.3.1
# annotated_types             0.5.0
# anyio                       NA
# arrow                       1.2.3
# asttokens                   NA
# async_timeout               4.0.3
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.14.0
# backcall                    0.2.0
# backoff                     2.2.1
# brotli                      NA
# bs4                         4.12.2
# certifi                     2024.07.04
# cffi                        1.15.1
# charset_normalizer          3.2.0
# chex                        0.1.83
# click                       8.1.5
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.1.3
# contextlib2                 NA
# croniter                    NA
# cycler                      0.10.0
# cython_runtime              NA
# cytoolz                     0.12.3
# dask                        2024.5.1
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# deepdiff                    6.3.1
# defusedxml                  0.7.1
# dill                        0.3.8
# docrep                      0.3.2
# dot_parser                  NA
# executing                   1.2.0
# fastapi                     0.103.2
# fastjsonschema              NA
# filelock                    3.12.2
# flax                        0.6.1
# fqdn                        NA
# frozenlist                  1.4.1
# fsspec                      2023.6.0
# future                      0.18.3
# gmpy2                       2.1.2
# google                      NA
# h5py                        3.9.0
# html5lib                    1.1
# hyperopt                    0.2.7
# idna                        3.4
# igraph                      0.10.5
# importlib_resources         NA
# ipykernel                   6.24.0
# ipywidgets                  8.1.3
# isoduration                 NA
# jax                         0.4.13
# jaxlib                      0.4.12
# jedi                        0.18.2
# jinja2                      3.1.2
# joblib                      1.3.0
# json5                       0.9.25
# jsonpointer                 3.0.0
# jsonschema                  4.18.3
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.14.1
# jupyterlab_server           2.27.2
# kiwisolver                  1.4.4
# leidenalg                   0.10.0
# lightning                   2.0.8
# lightning_cloud             NA
# lightning_fabric            2.0.4
# lightning_utilities         0.9.0
# llvmlite                    0.40.1
# lz4                         4.3.3
# markupsafe                  2.1.3
# matplotlib                  3.7.2
# matplotlib_inline           0.1.6
# ml_collections              NA
# ml_dtypes                   0.2.0
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.5
# mudata                      0.2.3
# multidict                   6.0.5
# multipart                   0.0.6
# multipledispatch            0.6.0
# natsort                     8.4.0
# nbformat                    5.10.4
# networkx                    3.1
# numba                       0.57.1
# numexpr                     2.10.0
# numpy                       1.24.4
# numpyro                     0.12.1
# nvfuser                     NA
# opt_einsum                  v3.3.0
# optax                       0.1.5
# ordered_set                 4.1.0
# orjson                      3.9.2
# overrides                   NA
# packaging                   23.1
# pandas                      2.2.2
# parso                       0.8.3
# past                        0.18.3
# patsy                       0.5.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.8.1
# prometheus_client           NA
# prompt_toolkit              3.0.39
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# py4j                        0.10.9.7
# pyarrow                     16.1.0
# pydantic                    2.8.2
# pydantic_core               2.20.1
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pydot                       1.4.2
# pygments                    2.15.1
# pyparsing                   3.0.9
# pyro                        1.8.4+9ed468d
# pythonjsonlogger            NA
# pytorch_lightning           2.0.4
# pytz                        2023.3
# ray                         2.7.0
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# scipy                       1.11.1
# scvi                        1.0.2
# seaborn                     0.12.2
# send2trash                  NA
# session_info                1.0.0
# setproctitle                1.2.2
# six                         1.16.0
# sklearn                     1.3.0
# sniffio                     1.3.0
# socks                       1.7.1
# soupsieve                   2.3.2.post1
# sparse                      0.14.0
# stack_data                  0.6.2
# starlette                   0.27.0
# statsmodels                 0.14.0
# sympy                       1.12
# tblib                       3.0.0
# texttable                   1.6.7
# threadpoolctl               3.2.0
# tlz                         0.12.3
# tomli                       2.0.1
# toolz                       0.12.0
# torch                       2.0.1
# torchmetrics                0.11.4
# torchvision                 0.15.2
# tornado                     6.3.2
# tqdm                        4.65.0
# traitlets                   5.9.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     1.26.15
# uvicorn                     0.22.0
# uvloop                      0.19.0
# watchfiles                  0.22.0
# wcwidth                     0.2.6
# webcolors                   24.6.0
# webencodings                0.5.1
# websocket                   1.6.1
# websockets                  11.0.3
# xarray                      2023.6.0
# yaml                        6.0
# yarl                        1.9.4
# zipp                        NA
# zmq                         25.1.0
# zoneinfo                    NA
# -----
# IPython             8.14.0
# jupyter_client      8.3.0
# jupyter_core        5.3.1
# jupyterlab          4.2.3
# notebook            7.2.1
# -----
# Python 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
# Linux-6.5.0-44-generic-x86_64-with-glibc2.35
# -----
# Session information updated at 2024-09-04 11:24

# %%
# set a working directory
wdir = '/media/prom/apc1/ccohen/chromium/analysis/20240711_Achilles/'
os.chdir( wdir )

# create an output directory with today's date and time
year = e.strftime("%Y")
month = e.strftime("%m")
day = e.strftime("%d")
hour = e.strftime('%H')
minute = e.strftime('%M')
dmyt = f'{year}{month}{day}_{hour}-{minute}'
directory = f'{dmyt}_scVI_on_harmony_integrated.dir'

# folder structures
RESULTS_FOLDERNAME = f'{directory}/results/'
FIGURES_FOLDERNAME = f'{directory}/figures/'

if not os.path.exists(RESULTS_FOLDERNAME):
    os.makedirs(RESULTS_FOLDERNAME)
if not os.path.exists(FIGURES_FOLDERNAME):
    os.makedirs(FIGURES_FOLDERNAME)
    
# Set folder for saving figures into
sc.settings.figdir = FIGURES_FOLDERNAME

print(directory)
# Out:
# 20240904_11-24_scVI_on_harmony_integrated.dir

# %%
path = os.path.join(wdir, 'data/integrated_objects/20240904_10-43_convert-objects.dir/Achilles_integrated_annotated.h5ad')
path
# Out:
# '/media/prom/apc1/ccohen/chromium/analysis/20240711_Achilles/data/integrated_objects/20240904_10-43_convert-objects.dir/Achilles_integrated_annotated.h5ad'

# %% [markdown]
# ### Read in adata object
# This Achilles data object has been integrated using Harmony.

# %%
adata = sc.read_h5ad(path)
adata
# Out:
# AnnData object with n_obs × n_vars = 67668 × 61552
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'sum', 'detected', 'subsets_mito_sum', 'subsets_mito_detected', 'subsets_mito_percent', 'total', 'log10GenesPerUMI', 'patient', 'age', 'sex', 'ethnicity', 'surgical_procedure', 'disease_status', 'anatomical_site', 'affected_side', 'time_to_freezing', 'sequencing_date', 'microanatomical_site', 'seurat_clusters', 'decontX_contamination', 'decontX_clusters', 'sizeFactor', 'scDblFinder.cluster', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.difficulty', 'scDblFinder.cxds_score', 'scDblFinder.mostLikelyOrigin', 'scDblFinder.originAmbiguous', 'RNA_snn_res.0.1', 'RNA_snn_res.0.2', 'RNA_snn_res.0.3', 'nCount_decontXcounts', 'nFeature_decontXcounts', 'nCount_soupX', 'nFeature_soupX', 'patient.seqbatch', 'soupX_snn_res.0.1', 'soupX_snn_res.0.2', 'soupX_snn_res.0.3', 'soupX_snn_res.0.4', 'soupX_snn_res.0.5', 'soupX_snn_res.0.6', 'soupX_snn_res.0.7', 'soupX_snn_res.0.8', 'soupX_snn_res.0.9', 'soupX_snn_res.1'
#     var: 'rownames(so)'
#     obsm: 'pca'
#     layers: 'counts', 'logcounts', 'soupX'

# %%
# scvi works with raw counts
adata.X = adata.layers['counts'].copy()

# %%
# calculate 5000 hvg and subset to those genes
sc.pp.highly_variable_genes(adata, 
                            n_top_genes= 5000, 
                            flavor='seurat_v3', 
                            batch_key='patient.seqbatch',
                            subset = True, 
                           span=0.5) # increase from default of 0.3 to avoid error
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 67668 × 5000
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'sum', 'detected', 'subsets_mito_sum', 'subsets_mito_detected', 'subsets_mito_percent', 'total', 'log10GenesPerUMI', 'patient', 'age', 'sex', 'ethnicity', 'surgical_procedure', 'disease_status', 'anatomical_site', 'affected_side', 'time_to_freezing', 'sequencing_date', 'microanatomical_site', 'seurat_clusters', 'decontX_contamination', 'decontX_clusters', 'sizeFactor', 'scDblFinder.cluster', 'scDblFinder.class', 'scDblFinder.score', 'scDblFinder.weighted', 'scDblFinder.difficulty', 'scDblFinder.cxds_score', 'scDblFinder.mostLikelyOrigin', 'scDblFinder.originAmbiguous', 'RNA_snn_res.0.1', 'RNA_snn_res.0.2', 'RNA_snn_res.0.3', 'nCount_decontXcounts', 'nFeature_decontXcounts', 'nCount_soupX', 'nFeature_soupX', 'patient.seqbatch', 'soupX_snn_res.0.1', 'soupX_snn_res.0.2', 'soupX_snn_res.0.3', 'soupX_snn_res.0.4', 'soupX_snn_res.0.5', 'soupX_snn_res.0.6', 'soupX_snn_res.0.7', 'soupX_snn_res.0.8', 'soupX_snn_res.0.9', 'soupX_snn_res.1', '_scvi_batch', '_scvi_labels'
#     var: 'rownames(so)', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: 'pca'
#     layers: 'counts', 'logcounts', 'soupX'

# %% [markdown]
# ### Optimise the scVI model using ray

# %%
# set up the object and view the available paramaters that can be tuned

model_cls = scvi.model.SCVI
model_cls.setup_anndata(adata, layer="counts", 
                        batch_key='patient.seqbatch')

scvi_tuner = autotune.ModelTuner(model_cls)
scvi_tuner.info()
# Out:
# ModelTuner registry for SCVI
#                   Tunable hyperparameters
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃      Hyperparameter      ┃ Default value ┃    Source    ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │         n_hidden         │      128      │     VAE      │
# │         n_latent         │      10       │     VAE      │
# │         n_layers         │       1       │     VAE      │
# │       dropout_rate       │      0.1      │     VAE      │
# │        dispersion        │     gene      │     VAE      │
# │     gene_likelihood      │     zinb      │     VAE      │
# │   latent_distribution    │    normal     │     VAE      │
# │    encode_covariates     │     False     │     VAE      │
# │ deeply_inject_covariates │     True      │     VAE      │
# │      use_batch_norm      │     both      │     VAE      │
# │      use_layer_norm      │     none      │     VAE      │
# │        optimizer         │     Adam      │ TrainingPlan │
# │            lr            │     0.001     │ TrainingPlan │
# │       weight_decay       │     1e-06     │ TrainingPlan │
# │           eps            │     0.01      │ TrainingPlan │
# │    n_steps_kl_warmup     │     None      │ TrainingPlan │
# │    n_epochs_kl_warmup    │      400      │ TrainingPlan │
# │   reduce_lr_on_plateau   │     False     │ TrainingPlan │
# │        lr_factor         │      0.6      │ TrainingPlan │
# │       lr_patience        │      30       │ TrainingPlan │
# │       lr_threshold       │      0.0      │ TrainingPlan │
# │          lr_min          │       0       │ TrainingPlan │
# │      max_kl_weight       │      1.0      │ TrainingPlan │
# │      min_kl_weight       │      0.0      │ TrainingPlan │
# └──────────────────────────┴───────────────┴──────────────┘
#        Available metrics
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃     Metric      ┃    Mode    ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ validation_loss │    min     │
# └─────────────────┴────────────┘
#                          Default search space
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Hyperparameter ┃ Sample function ┃  Arguments  ┃ Keyword arguments ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │    n_hidden    │     choice      │ [[64, 128]] │        {}         │
# └────────────────┴─────────────────┴─────────────┴───────────────────┘

# %%
# specify which variables will be tested
search_space = {
    "n_latent": tune.choice([10, 30, 50]),
    "n_hidden": tune.choice([60, 128, 256]),
    "n_layers": tune.choice([1, 2, 3]),
    "lr": tune.loguniform(1e-4, 1e-2),
    "gene_likelihood": tune.choice(["nb", "zinb"])
}

# %%
ray.init(log_to_driver=False)
# Out:
# 2024-09-04 11:33:31,668	INFO worker.py:1633 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.16', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)

# %%
# run the optimisation

results = scvi_tuner.fit(
    adata,
    metric="validation_loss",
    search_space=search_space,
    searcher='hyperopt',
    num_samples=100,
    max_epochs=30,
    resources={"gpu": 1}
)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-09-04 14:12:22</td></tr>
# <tr><td>Running for: </td><td>01:46:24.13        </td></tr>
# <tr><td>Memory:      </td><td>246.2/503.5 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=84<br>Bracket: Iter 64.000: None | Iter 32.000: None | Iter 16.000: -1037.344482421875 | Iter 8.000: -1041.61279296875 | Iter 4.000: -1056.7451171875 | Iter 2.000: -1076.7453002929688 | Iter 1.000: -1107.74755859375<br>Logical resource usage: 0/128 CPUs, 1.0/2 GPUs (0.0/1.0 accelerator_type:RTX)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>loc                </th><th style="text-align: right;">  n_latent</th><th style="text-align: right;">  n_hidden</th><th style="text-align: right;">  n_layers</th><th style="text-align: right;">         lr</th><th>gene_likelihood  </th><th style="text-align: right;">  validation_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>_trainable_84825231</td><td>TERMINATED</td><td>163.1.64.158:692540</td><td style="text-align: right;">        30</td><td style="text-align: right;">       256</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.00783798 </td><td>nb               </td><td style="text-align: right;">          1052.42</td></tr>
# <tr><td>_trainable_af2254cb</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        30</td><td style="text-align: right;">       128</td><td style="text-align: right;">         1</td><td style="text-align: right;">0.00977074 </td><td>nb               </td><td style="text-align: right;">          1085.76</td></tr>
# <tr><td>_trainable_deedc7a7</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        30</td><td style="text-align: right;">        60</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.00815043 </td><td>nb               </td><td style="text-align: right;">          1107.3 </td></tr>
# <tr><td>_trainable_e3b3426b</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       256</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.000147773</td><td>zinb             </td><td style="text-align: right;">          1169.94</td></tr>
# <tr><td>_trainable_75e5c12f</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        10</td><td style="text-align: right;">       256</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.000215706</td><td>nb               </td><td style="text-align: right;">          1189.72</td></tr>
# <tr><td>_trainable_399cfe89</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        10</td><td style="text-align: right;">        60</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.00325564 </td><td>zinb             </td><td style="text-align: right;">          1111.48</td></tr>
# <tr><td>_trainable_ea48c6cc</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        10</td><td style="text-align: right;">        60</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.00210706 </td><td>nb               </td><td style="text-align: right;">          1143.49</td></tr>
# <tr><td>_trainable_50e1d4e1</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       256</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.000979989</td><td>zinb             </td><td style="text-align: right;">          1113.97</td></tr>
# <tr><td>_trainable_6996b1ea</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        30</td><td style="text-align: right;">       256</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.000223102</td><td>zinb             </td><td style="text-align: right;">          1156.43</td></tr>
# <tr><td>_trainable_d76d3a2e</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       128</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.000386432</td><td>zinb             </td><td style="text-align: right;">          1164.93</td></tr>
# <tr><td>_trainable_71729fd7</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       128</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.00182842 </td><td>zinb             </td><td style="text-align: right;">          1086.04</td></tr>
# <tr><td>_trainable_72538b04</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       128</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.000677788</td><td>zinb             </td><td style="text-align: right;">          1138.15</td></tr>
# <tr><td>_trainable_a670e211</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        30</td><td style="text-align: right;">        60</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.00117678 </td><td>nb               </td><td style="text-align: right;">          1173.65</td></tr>
# <tr><td>_trainable_57893b3e</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        10</td><td style="text-align: right;">       256</td><td style="text-align: right;">         1</td><td style="text-align: right;">0.000108994</td><td>zinb             </td><td style="text-align: right;">          1198.54</td></tr>
# <tr><td>_trainable_468caf72</td><td>TERMINATED</td><td>163.1.64.158:692888</td><td style="text-align: right;">        50</td><td style="text-align: right;">       128</td><td style="text-align: right;">         1</td><td style="text-align: right;">0.00289398 </td><td>nb               </td><td style="text-align: right;">          1046.72</td></tr>
# <tr><td>_trainable_9b6d5c14</td><td>TERMINATED</td><td>163.1.64.158:692540</td><td style="text-align: right;">        50</td><td style="text-align: right;">       256</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.000305553</td><td>zinb             </td><td style="text-align: right;">          1145.89</td></tr>
# <tr><td>_trainable_47377bbd</td><td>TERMINATED</td><td>163.1.64.158:692540</td><td style="text-align: right;">        10</td><td style="text-align: right;">        60</td><td style="text-align: right;">         1</td><td style="text-align: right;">0.00733263 </td><td>nb               </td><td style="text-align: right;">          1068.57</td></tr>
# <tr><td>_trainable_6ddbca80</td><td>TERMINATED</td><td>163.1.64.158:692540</td><td style="text-align: right;">        30</td><td style="text-align: right;">       128</td><td style="text-align: right;">         2</td><td style="text-align: right;">0.000865559</td><td>nb               </td><td style="text-align: right;">          1151.98</td></tr>
# <tr><td>_trainable_d4e84dcc</td><td>TERMINATED</td><td>163.1.64.158:692540</td><td style="text-align: right;">        30</td><td style="text-align: right;">       128</td><td style="text-align: right;">         3</td><td style="text-align: right;">0.000224243</td><td>zinb             </td><td style="text-align: right;">          1193.69</td></tr>
# <tr><td>_trainable_ce68d56b</td><td>TERMINATED</td><td>163
# 2024-09-04 12:25:58,048	INFO tune.py:645 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# (pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
# (pid=692540)   self.seed = seed
# (pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
# (pid=692540)   self.dl_pin_memory_gpu_training = (
# (pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
# (pid=692540)   jax.tree_util.register_keypaths(data_clz, keypaths)
# (pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
# (pid=692540)   jax.tree_util.register_keypaths(data_clz, keypaths)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/ray/tune/integration/pytorch_lightning.py:194: UserWarning: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_trainable pid=692540)   warnings.warn(
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) You are using a CUDA device ('NVIDIA RTX 6000 Ada Generation') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:63: UserWarning: Since v1.0.0, scvi-tools no longer uses a random seed by default. Run `scvi.settings.seed = 0` to reproduce results from previous versions.
# (pid=692888)   self.seed = seed
# (pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/_settings.py:70: UserWarning: Setting `dl_pin_memory_gpu_training` is deprecated in v1.0 and will be removed in v1.1. Please pass in `pin_memory` to the data loaders instead.
# (pid=692888)   self.dl_pin_memory_gpu_training = (
# (pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead. [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (pid=692888)   jax.tree_util.register_keypaths(data_clz, keypaths) [repeated 2x across cluster]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization. [repeated 2x across cluster]
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key) [repeated 2x across cluster]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/ray/tune/integration/pytorch_lightning.py:194: UserWarning: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_trainable pid=692888)   warnings.warn(
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) You are using a CUDA device ('NVIDIA RTX 6000 Ada Generation') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692888) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692888) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692888) `Trainer.fit` stopped: `max_epochs=30` reached.
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692888)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692888) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692888)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692888) GPU available: True (cuda), used: True
# (_trainable pid=692888) TPU available: False, using: 0 TPU cores
# (_trainable pid=692888) IPU available: False, using: 0 IPUs
# (_trainable pid=692888) HPU available: False, using: 0 HPUs
# (_trainable pid=692888) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
# (_trainable pid=692540)   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)
# (_trainable pid=692540) /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/train/_trainrunner.py:76: UserWarning: `use_gpu` is deprecated in v1.0 and will be removed in v1.1. Please use `accelerator` and `devices` instead.
# (_trainable pid=692540)   accelerator, lightning_devices, device = parse_device_args(
# (_trainable pid=692540) GPU available: True (cuda), used: True
# (_trainable pid=692540) TPU available: False, using: 0 TPU cores
# (_trainable pid=692540) IPU available: False, using: 0 IPUs
# (_trainable pid=692540) HPU available: False, using: 0 HPUs
# (_trainable pid=692540) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2024-09-04 14:12:22,204	INFO tune.py:1143 -- Total run time: 6384.16 seconds (6384.11 seconds for the tuning loop).

# %% [markdown]
# We are looking for the parameters that give the lowest validation loss

# %%
print(results.model_kwargs)
print(results.train_kwargs)
# Out:
# {'n_latent': 50, 'n_hidden': 256, 'n_layers': 1, 'gene_likelihood': 'nb'}
# {'plan_kwargs': {'lr': 0.003413161340390653}}

# %%
df = results.results.get_dataframe()
df2 = df.sort_values(by = 'validation_loss').reset_index()
df2
# Out:
#     index  validation_loss   timestamp   done  training_iteration  trial_id  \
# 0      60      1030.701782  1725453157  False                  30  81158bb7
# 1      79      1032.044434  1725454574  False                  30  fa205d9d
# 2      87      1032.867310  1725455160  False                  30  5b0d3662
# 3      40      1033.244385  1725452352  False                  30  b8a2c846
# 4      65      1033.640869  1725453524  False                  30  e666d0dd
# ..    ...              ...         ...    ...                 ...       ...
# 95     55      1186.216797  1725452590   True                   1  f21ccdb8
# 96      4      1189.715942  1725449257   True                   1  75e5c12f
# 97     18      1193.686523  1725449835   True                   1  d4e84dcc
# 98     13      1198.543335  1725449443   True                   1  57893b3e
# 99     50      1405.760864  1725452532   True                   1  902ea17d
#
#                    date  time_this_iter_s  time_total_s     pid  ...  \
# 0   2024-09-04_13-32-37         17.501318    518.029619  692888  ...
# 1   2024-09-04_13-56-14         17.765750    534.863467  692540  ...
# 2   2024-09-04_14-06-00         18.157649    537.744939  692888  ...
# 3   2024-09-04_13-19-12         17.275873    524.532700  692888  ...
# 4   2024-09-04_13-38-44         17.581520    526.444979  692540  ...
# ..                  ...               ...           ...     ...  ...
# 95  2024-09-04_13-23-10         18.063239     18.063239  692540  ...
# 96  2024-09-04_12-27-37         18.232076     18.232076  692888  ...
# 97  2024-09-04_12-37-15         18.679745     18.679745  692540  ...
# 98  2024-09-04_12-30-43         17.836543     17.836543  692888  ...
# 99  2024-09-04_13-22-12         18.512707     18.512707  692888  ...
#
#          node_ip time_since_restore  iterations_since_restore  \
# 0   163.1.64.158         518.029619                        30
# 1   163.1.64.158         534.863467                        30
# 2   163.1.64.158         537.744939                        30
# 3   163.1.64.158         524.532700                        30
# 4   163.1.64.158         526.444979                        30
# ..           ...                ...                       ...
# 95  163.1.64.158          18.063239                         1
# 96  163.1.64.158          18.232076                         1
# 97  163.1.64.158          18.679745                         1
# 98  163.1.64.158          17.836543                         1
# 99  163.1.64.158          18.512707                         1
#
#     checkpoint_dir_name config/n_latent  config/n_hidden  config/n_layers  \
# 0                  None              50              256                1
# 1                  None              50              256                1
# 2                  None              50              256                2
# 3                  None              50              256                1
# 4                  None              50              256                1
# ..                  ...             ...              ...              ...
# 95                 None              50              256                1
# 96                 None              10              256                2
# 97                 None              30              128                3
# 98                 None              10              256                1
# 99                 None              10               60                3
#
#     config/lr  config/gene_likelihood    logdir
# 0    0.003413                      nb  81158bb7
# 1    0.004508                    zinb  fa205d9d
# 2    0.006364                    zinb  5b0d3662
# 3    0.002195                      nb  b8a2c846
# 4    0.004013                      nb  e666d0dd
# ..        ...                     ...       ...
# 95   0.000254                      nb  f21ccdb8
# 96   0.000216                      nb  75e5c12f
# 97   0.000224                    zinb  d4e84dcc
# 98   0.000109                    zinb  57893b3e
# 99   0.000135                    zinb  902ea17d
#
# [100 rows x 21 columns]

# %%
print("Index of optimal parameters")
row_number = df2['index'][0]
row_number
# Out:
# Index of optimal parameters
# 60

# %%
print("Optimal parameters")
df.iloc[row_number]
# Out:
# Optimal parameters
# validation_loss                     1030.701782
# timestamp                            1725453157
# done                                      False
# training_iteration                           30
# trial_id                               81158bb7
# date                        2024-09-04_13-32-37
# time_this_iter_s                      17.501318
# time_total_s                         518.029619
# pid                                      692888
# hostname                            BRC-89SJ904
# node_ip                            163.1.64.158
# time_since_restore                   518.029619
# iterations_since_restore                     30
# checkpoint_dir_name                        None
# config/n_latent                              50
# config/n_hidden                             256
# config/n_layers                               1
# config/lr                              0.003413
# config/gene_likelihood                       nb
# logdir                                 81158bb7
# Name: 60, dtype: object

# %%
ray.shutdown()

# %% [markdown]
# ### Run scVI using optimised parameters

# %%
# set up the adata object
scvi.model.SCVI.setup_anndata(adata,
                              layer = 'counts',
                              batch_key = "patient.seqbatch"
                             )
# Out:
# /media/prom/apc1/ccohen/mamba_installation/conda/envs/scvi_env/lib/python3.9/site-packages/scvi/data/fields/_layer_field.py:101: UserWarning: Training will be faster when sparse matrix is formatted as CSR. It is safe to cast before model initialization.
#   _verify_and_correct_data_format(adata, self.attr_name, self.attr_key)

# %%
# set up the scVI model
# specify the parameters according to the ray optimisation
vae = scvi.model.SCVI(adata,
                      n_latent = 50,  
                      n_hidden = 256, 
                      n_layers =  1, 
                      dropout_rate = 0.1,
                      dispersion = 'gene-batch',
                     gene_likelihood='nb')

vae
# Out:
# SCVI Model with the following params:
# n_hidden: 256, n_latent: 50, n_layers: 1, dropout_rate: 0.1, dispersion: gene-batch, gene_likelihood: nb,
# latent_distribution: normal
# Training status: Not Trained
# Model's adata is minified?: False

# %%
# add the parameter for lr
kwargs = {'lr': 0.003413}

# %%
 vae.view_anndata_setup(adata) # check the set up looks as expected
# Out:
# Anndata setup with scvi-tools version 1.0.2.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Setup via `SCVI.setup_anndata` with arguments:
# {
# │   'layer': 'counts',
# │   'batch_key': 'patient.seqbatch',
# │   'labels_key': None,
# │   'size_factor_key': None,
# │   'categorical_covariate_keys': None,
# │   'continuous_covariate_keys': None
# }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#          Summary Statistics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃     Summary Stat Key     ┃ Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │         n_batch          │   8   │
# │         n_cells          │ 67668 │
# │ n_extra_categorical_covs │   0   │
# │ n_extra_continuous_covs  │   0   │
# │         n_labels         │   1   │
# │          n_vars          │ 5000  │
# └──────────────────────────┴───────┘
#                Data Registry
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registry Key ┃    scvi-tools Location    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      X       │  adata.layers['counts']   │
# │    batch     │ adata.obs['_scvi_batch']  │
# │    labels    │ adata.obs['_scvi_labels'] │
# └──────────────┴───────────────────────────┘
#                            batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Source Location        ┃    Categories    ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['patient.seqbatch'] │ MSK0785_11102021 │          0          │
# │                               │ MSK1250_11102021 │          1          │
# │                               │ MSK1250_20230822 │          2          │
# │                               │ MSK1284_11102021 │          3          │
# │                               │ MSK1556_20220808 │          4          │
# │                               │ MSK1556_20230822 │          5          │
# │                               │ MSK1687_20230822 │          6          │
# │                               │ MSK1691_20230822 │          7          │
# └───────────────────────────────┴──────────────────┴─────────────────────┘
#                      labels State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘

# %%
# calculate the number of epochs needed which varies according to the cell number
max_epochs_scvi = int(np.min([round((20000 / adata.n_obs) * 400), 400])) # must be an integer
max_epochs_scvi
# Out:
# 118

# %%
# run the training (need the GPU queue here)
# updated to 60 epochs due to overfitting
vae.train(max_epochs = 60, 
          train_size = 0.9, 
          validation_size = 0.1, 
          accelerator='gpu', 
          check_val_every_n_epoch=1,
          early_stopping=True,
          early_stopping_patience=10,
          early_stopping_monitor="elbo_validation",
          plan_kwargs = kwargs
         )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA RTX 6000 Ada Generation') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 60/60: 100%|█| 60/60 [15:32<00:00, 15.57s/it, v_num=1, train_loss_step=1.0
# `Trainer.fit` stopped: `max_epochs=60` reached.
# Epoch 60/60: 100%|█| 60/60 [15:32<00:00, 15.55s/it, v_num=1, train_loss_step=1.0

# %%
# visualise the results of the training
train_test_results = vae.history["elbo_train"]
train_test_results["elbo_validation"] = vae.history["elbo_validation"]
train_test_results.iloc[10:].plot(logy=True)  # exclude first 10 epochs
plt.show()

# %%
y = vae.history['reconstruction_loss_validation']['reconstruction_loss_validation'].min()
plt.plot(vae.history['reconstruction_loss_train']['reconstruction_loss_train'], label='train')
plt.plot(vae.history['reconstruction_loss_validation']['reconstruction_loss_validation'], label='validation')
plt.axhline(y, c = 'k')
plt.legend()
plt.show()

# %%
# save the trained model
# in file name use: sample, covariate, nepochs, n_hidden, n_latent, n_layers, dropout rate, dispersion, gene likelihood
vae.save(os.path.join(RESULTS_FOLDERNAME, "Ach_patient.seqbach_60_256_50_1_01_gene-batch_zinb/"), overwrite=True)

# %%
# Extract latent representation embeddings from your trained model 
adata.obsm["X_scVI"] = vae.get_latent_representation()

# %%
# save the object
adata.write(os.path.join(RESULTS_FOLDERNAME, 'Achilles_scVI.h5ad'))

# %%
# Save the scVI embeddings as numpy array
filename = RESULTS_FOLDERNAME + "scVI_embeddings"
np.save(filename, adata.obsm['X_scVI'])

# %%
# Save the metadata
filename = RESULTS_FOLDERNAME + "Achilles_scVI_obs.txt"
adata.obs.to_csv(filename, sep='\t')
